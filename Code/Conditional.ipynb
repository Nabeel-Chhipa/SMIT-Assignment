# %% [markdown]
# # 1

# %%
number = int(input('Enter a number'))
if (number % 2) == 0:
    print(f'{number} is even number')
else:
    print(f'{number} is odd number')
# Out:
# Enter a number 3
# 3 is odd number

# %% [markdown]
# # 2

# %%
age = int(input('Enter your age'))
if age >= 18:
    print('You are eligible for vote')
else:
    print('You are not eligible for vote')
# Out:
# Enter your age 20
# You are eligible for vote

# %% [markdown]
# # 3

# %%
number_1 = int(input('Enter number one'))
number_2 = int(input('Enter number two'))
if number_1 > number_2:
    print(f'{number_1} is grater than number {number_2}')
elif number_1 == number_2:
    print(f'{number_1} and {number_2} both are same')
else:
    print(f'{number_1} is less than number {number_2}')
# Out:
# Enter number one 2
# Enter number two 1
# 2 is grater than number 1

# %% [markdown]
# # 4

# %%
user_input = int(input('Enter a number'))
if user_input > 0:
    print(f'{user_input} is a positive number')
elif user_input < 0:
    print(f'{user_input} is a negative number')
elif user_input == 0:
    print('Zero')
# Out:
# Enter a number -2
# -2 is a negative number

# %% [markdown]
# # 5

# %%
citizen_age = int(input('Enter your age to find your age group'))
if citizen_age < 0:
    print('Please enter correct age')
elif citizen_age == 0 or citizen_age <= 12:
    print('You are child')
elif citizen_age == 13 or citizen_age <= 19:
    print('You are Teenager')
elif citizen_age == 20 or citizen_age <= 59:
    print('You are Adult')
elif citizen_age > 59:
    print('You are Senior Citizen')
# Out:
# Enter your age to find your age group 60
# You are Senior Citizen

# %% [markdown]
# # 6

# %%
week_days = ['Monnday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
number = int(input('Enter a number between 0 to 7: '))
for i, day in enumerate(week_days):
    if number == i:
        print(f'Today is: {week_days[i]}')
    
if number >= 7:
        print('Please enter number only between 0 to 7. Number must be less than or equal to 7')
# Out:
# Enter a number between 0 to 7:  0
# Today is: Monnday

# %% [markdown]
# # 7

# %%
weight = float(input('Enter your weight in kg'))
height = float(input('Enter your height in meters'))
BMI = weight / (height * height)
if BMI < 18.5:
    print(f'{BMI:.2f} is Underweight')
elif BMI > 18.5 and BMI < 24.9:
    print(f'{BMI:.2f} is normal weight')
elif BMI > 24.9 and BMI < 29.9:
    print(f'{BMI:.2f} is Overweight')
elif BMI > 30:
    print(f'{BMI:.2f} is Obesity')
# print(f'{BMI:.2f}')
# Out:
# Enter your weight in kg 75
# Enter your height in meters 1
# 75.00 is Obesity

# %% [markdown]
# # 8

# %%
subject_1 = int(input('Enter subject 1 marks'))
subject_2 = int(input('Enter subject 2 marks'))
subject_3 = int(input('Enter subject 3 marks'))
grade = ''
average = (subject_1 + subject_2 + subject_3) / 3
if 90 <= average <= 100:
    grade = 'A'
elif 80 <= average <= 89:
    grade = 'B'
elif 70 <= average <= 79:
    grade = 'C'
elif 60 <= average <= 69:
    grade = 'D'
else:
    grade = 'F'
print(f'Grade: {grade}\nAverage {average}')
# Out:
# Enter subject 1 marks 3
# Enter subject 2 marks 4
# Enter subject 3 marks 5
# Grade: F
# Average 4.0

# %% [markdown]
# # 9

# %%
num_1 = float(input('Enter number one'))
num_2 = float(input('Enter number two'))
num_3 = float(input('Enter number three'))
temp_numbers = [num_1, num_2, num_3]

temp_numbers.sort()
print(temp_numbers)
# Out:
# Enter number one 2
# Enter number two 3
# Enter number three 9
# [2.0, 3.0, 9.0]

# %% [markdown]
# # 10

# %%
number_1 = int(input('Enter number 1'))
number_2 = int(input('Enter number 2'))
number_3 = int(input('Enter number 3'))
temp_list = [number_1, number_2, number_3]
max(temp_list)
# Out:
# Enter number 1 20
# Enter number 2 1
# Enter number 3 9
# 20

# %% [markdown]
# # 11

# %%
character = input('Enter a character')
vowels = ['a', 'e', 'i', 'o', 'u']
if character in vowels:
    print(f'{character} is vowel')
else:
    print(f'{character} is consonant')
# Out:
# Enter a character k
# k is consonant

# %% [markdown]
# # 12

# %%
year = int(input('Enter a year'))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f'{year} is a leap year')
else:
    print(f'{year} is not a leap year')
# Out:
# Enter a year 1995
# 1995 is not a leap year
