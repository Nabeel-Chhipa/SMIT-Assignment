# %% [markdown]
# # Topic: print()

# %% [markdown]
# 1) Using the python print function print any string value, integer value, boolean value, float value in single print command

# %%
print("Hello", 12, True, 12.3, sep=" ")
# Out:
# Hello 12 True 12.3

# %% [markdown]
# 2) Using the python print function print hyphon(-) separated any string value, integer value, boolean value, float value in single print command

# %%
print("Hello", 12, True, 12.3, sep="-")
# Out:
# Hello-12-True-12.3

# %% [markdown]
# 3) Using the python print function print any string value, integer value, boolean value, float value in separate print command.
# But every value must be space separated and in single line

# %%
print("Hello", end=" ")
print(12, end=" ")
print(False, end=" ")
print(56.78)
# Out:
# Hello 12 False 56.78

# %% [markdown]
# 4) Can a python print function take no value to print???

# %%
print()

# %% [markdown]
# # TOPIC :Variables in Python Operators

# %% [markdown]
# 5) One of my friends name is Mr. Ahmed. He is 30 years old.  He is a lawer by profession. He has done his bachelors in law in the year 2005. He is working with a reputable law firm 'The Himalya Associates' in Karachi since 2015.
# He is a handsome lawer with height of 5.10 feets and weight 70600g. His monthly income is Rs. 200k PKR.
#
# Note: Create variables from above text and also assign values from the text.

# %%
name = input("Enter your friend's name")
age = int(input("Enter age"))
profession = input("Enter profession")
bachelors_education = input("Enter bachelors education")
passing_year = int(input("Enter passing year"))
company_name = input("Enter company name")
city_name = input("Enter city name")
joining_year = int(input("Enter joining year"))
height = float(input("Enter height"))
weight = float(input("Enter weight"))
salary = float(input("Enter salary"))

print(f"\nFriend's Data\n\n One of my friends name is {name}. He is {age} years old. He is a {profession} by profession. He has done his bachelors in {bachelors_education} in the year {passing_year}. He is working with a reputable {profession} firm {company_name} in {city_name} since {joining_year}. He is a handsome {profession} with height of {height} feets and weight {weight}g. His monthly income is Rs. {salary} PKR.")
# Out:
# Enter your friend's name Muhammad Nabeel
# Enter age 28
# Enter profession Data Scientist & AI Engineer
# Enter bachelors education MS Data Science & AI
# Enter passing year 2018
# Enter company name Decibel
# Enter city name Karachi
# Enter joining date 2015
# Enter height 5.8
# Enter weight 75.5
# Enter salary 120000
# Friend's Data
#
#  One of my friends name is Muhammad Nabeel. He is 28 years old. He is a Data Scientist & AI Engineer by profession. He has done his bachelors in MS Data Science & AI in the year 2018. He is working with a reputable Data Scientist & AI Engineer firm Decibel in Karachi since 2015. He is a handsome Data Scientist & AI Engineer with height of 5.8 feets and weight 75.5g. His monthly income is Rs. 120000.0 PKR.

# %% [markdown]
# 6)How many years has been to Mr. Ahmed after his bachelors degree? Create a variable that hold current year value and then subtract it from his passout year

# %%
current_year = 2024
current_year -= passing_year
print(current_year)
# Out:
# 6

# %% [markdown]
# 7) How many years has Mr. Ahmed been working with law firm 'The Himalya Associates'. Create necesary variables and print the correct number of years in working in the firm

# %%
year = 2024
total_working_duration = year - joining_year
print(total_working_duration)
# Out:
# 9

# %% [markdown]
# 8)Convert the monthly income of Mr. Ahmed in dollars.  Create necesary variables and print the income in dollars.

# %%
usd = 278
convert_usd = salary / usd
print(f"Salary in US dollar is ${convert_usd:.2f}")
# Out:
# Salary in US dollar is $431.65

# %% [raw]
# 9) Check if the income in dollars is a float or integer value. if it is float, re-write the code so that income gets converted in integer. print the income in integer type value

# %%
print(int(convert_usd))
# Out:
# 431

# %% [raw]
# 10) Print the type of Mr. Ahmed's weight. Convert the weight of Mr. Ahmed in kg so that weight must be a integer value.

# %%
print(int(weight))
# Out:
# 75

# %%
#11) print the year of birth of Mr. Ahmed.
# Out:
# 1994

# %%
from datetime import datetime

age = 28
# currentYear = 2024
currentYear = datetime.now().year
findYear = currentYear - age
print(findYear)
# Out:
# 1996

# %%
#type your code here

# %% [markdown]
# 12) Can Rs. 100 be divided equally among 6 students?
# HINT: % operator (modulo)

# %%
10%2
# 10 is completely divisible by2
# 10 is multiple of 2
# 2 is a factor of 10
# 10 comes in table of 2
# Out:
# 0

# %% [raw]
#                        Saylani Mass IT
#              Name   : Nasir Hussain
#              Course : AI and DS
#              Days   : Tuesday and Thursday
#              ID     : AI - 332909
